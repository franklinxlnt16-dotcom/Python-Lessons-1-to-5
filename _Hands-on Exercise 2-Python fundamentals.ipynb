# %% [markdown]
# ## Exercise 1

# %%
first_name = "Chukwuemeka"
current_age = 19
country_of_origin = "Nigeria"
print(first_name)
print(current_age)
print(country_of_origin)
# Out:
# Chukwuemeka
# 19
# Nigeria

# %% [markdown]
# ## Exercise 2

# %%
annual_salary = 792000
annual_bonus = 150000
total_salary = annual_salary + annual_bonus
print(total_salary)
# Out:
# 942000

# %% [markdown]
# ## Exercise 3

# %%
name = input("Enter your name: ")
programming_language = input("Your favorite programming language: ")
print("Hello", name)
print("Your favorite programming language is", programming_language)
# Out:
# Enter your name:  Chukwuemeka
# Your favorite programming language:  Python
# Hello Chukwuemeka
# Your favorite programming language is Python

# %% [markdown]
# ## Exercise 4

# %%
whole_number = 235
number_with_decimal = 20.53
random_word = "melanin"
logic_word = True
print(type(whole_number))
print(type(number_with_decimal))
print(type(random_word))
print(type(logic_word))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ## Exercise 5

# %%
random_integer = 154
print(type(random_integer))
random_integer = "workspace"
print(type(random_integer))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ## Mini Project

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
course = input("Enter your preferred course: ")
nationality = input("What's your country of origin: ")
print("Name :",type(name))
print("Age :",type(age))
print("Country :",type(course))
print("Country :",type(nationality))
print("=" * 36)
print("STUDENT INFORMATION CARD")
print("=" *36)
print()
print("Name :",name)
print("Age :",age)
print("Course :",course)
print("Country :",nationality)
print()
age = int(age)
print("After Conversion")
print()
print("Age:",age)
print()
print("Data Type:")
print(type(age))
# Out:
# Enter your name:  Chukwuemeka
# Enter your age:  19
# Enter your preferred course:  Python programming
# What's your country of origin:  Nicaragua
# Name : <class 'str'>
# Age : <class 'str'>
# Country : <class 'str'>
# Country : <class 'str'>
# ...
# STUDENT INFORMATION CARD
# ...
#
# Name : Chukwuemeka
# Age : 19
# Course : Python programming
# Country : Nicaragua
#
# After Conversion
#
# Age: 19
#
# Data Type:
# <class 'int'>
