# %% [markdown]
# ## Exercise 1

# %%
print("Hello World!\nMy name is Franklyn\nI am learning Python.\nProgramming is exciting!")
# Out:
# Hello World!
# My name is Franklyn
# I am learning Python.
# Programming is exciting!

# %% [markdown]
# ## Exercise 2

# %%
print("My favourite food is yamarita with sauce")
print("My favourite movie is Vincenzo")
print("My favourite sport is table tennis")
print("My favourite colour is cyan")
# Out:
# My favourite food is yamarita with sauce
# My favourite movie is Vincenzo
# My favourite sport is table tennis
# My favourite colour is cyan

# %% [markdown]
# ## Exercise 3

# %%
print(15+5)
print(30-12)
print(9*8)
print(72/9)
print(18%5)
print(10//3)
print(5**2)
# Out:
# 20
# 18
# 72
# 8.0
# 3
# 3
# 25

# %% [markdown]
# ## Exercise 4

# %%
# Display programming language
print("Python")
# Display action to be carried out
print("Programming")
# Output the first lesson heading
print("Lesson One")
# Out:
# Python
# Programming
# Lesson One

# %% [markdown]
# ## Exercise 5

# %%
print ("My name is Umeizudike Franklyn")
print("I want to become a Data scientist")
# Display my country of origin 
print("I am from Nigeria")
# Calculating the sum of 2 numbers
print(25+75)
# Calculating the floor division of two numbers
print(40//6)
# Calculating the exponent of a number
print(8**2)
# Out:
# My name is Umeizudike Franklyn
# I want to become a Data scientist
# I am from Nigeria
# 100
# 6
# 64
