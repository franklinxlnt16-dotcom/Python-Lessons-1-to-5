# %% [markdown]
# ## Exercise 1

# %%
customer_name = "Franklyn"
email_address = "frank@gmail.com"
phone_number = 7068646910
country = "Nicaragua"
occupation = "Data scientist"
print("Customer Registration")
print()
print(f"Name:\t{customer_name}")
print("Email:",email_address)
print("Phone:",phone_number)
print("Country:",country)
print("Occupation:",occupation)
# Out:
# Customer Registration
#
# Name:	Franklyn
# Email: frank@gmail.com
# Phone: 7068646910
# Country: Nicaragua
# Occupation: Data scientist

# %% [markdown]
# ## Exercise 2

# %%
patient_name = "Dorcas"
doctor = "Dr. Davis"
diagnosis = "type-2 Diabetes"
blood_group = "O+"
hospital = "Medical city Hospital"
print("PATIENT RECORD")
print()
print(f"""Patient: {patient_name}
Doctor: {doctor}
Diagnosis: {diagnosis }
Blood Group: {blood_group}
Hospital: {hospital}
""")
# Out:
# PATIENT RECORD
#
# Patient: Dorcas
# Doctor: Dr. Davis
# Diagnosis: type-2 Diabetes
# Blood Group: O+
# Hospital: Medical city Hospital

# %% [markdown]
# ## Exercise 3

# %%
instruction_prompt = """
You are an AI Assistant

Analyze customer feedback

Carry out a customer churn prediction

Identify common complaints

Provide recommendations

Generate a summary report
"""
print(instruction_prompt)
# Out:
# You are an AI Assistant
#
# Analyze customer feedback
#
# Carry out a customer churn prediction
#
# Identify common complaints
#
# Provide recommendations
#
# Generate a summary report

# %% [markdown]
# ## Case Study Project

# %%
customer_name = "Sarah Johnson"
product_name = "Wireless Mouse"
product_category = "Computer Accessories"
customer_rating = "5 Stars"
customer_review = """
'The product arrived on time,was easy to 
install, and exceeded my expectations.
I would definitely recommend it to others.'"""
print("="*46)
print("CUSTOMER FEEDBACK REPORT".center(46))
print("="*46)
print()
print(f"""Customer Name: {customer_name}
Product:       {product_name}
Category:      {product_category}
Rating:        {customer_rating}

Customer Review""")
print("-"*22)
print(customer_review)
print()
print("="*46)
print()
print("Thank you for your feedback!")
print("="*46)
# Out:
# ...
#            CUSTOMER FEEDBACK REPORT
# ...
#
# Customer Name: Sarah Johnson
# Product:       Wireless Mouse
# Category:      Computer Accessories
# Rating:        5 Stars
#
# Customer Review
# ----------------------
#
# 'The product arrived on time,was easy to
# install, and exceeded my expectations.
# I would definitely recommend it to others.'
#
# ...
#
# Thank you for your feedback!
# ...
