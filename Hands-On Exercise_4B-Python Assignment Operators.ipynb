# %% [markdown]
# ## Hands-On 1

# %%
score = int(input("Enter your score:",))
score += 15
score -= 5
score *= 2
print(score)
# Out:
# Enter your score: 73
# 166

# %% [markdown]
# ## Hands-On 2

# %% [markdown]
# balance = 25000
# balance += int(input("Enter Deposit Amount:",))
# balance -= int(input("Enter withdrawal amount:",))
# balance /= 3
# print(balance)
# print(type(balance))

# %% [markdown]
# ## Hands-On 3

# %%
stock = int(input("Initial Stock:",))
stock -= int(input("Quantity of items sold",))
print("Remaining stock after sales:",stock)
stock +=  int(input("Amount of new Stocks:",))
print("Updated stock after restocking:",stock)
stock //= 12
print("Number of full cartons:",stock)
stock %= 12
print("Remaining stocks:",stock)
# Out:
# Initial Stock: 560
# Quantity of items sold 57
# Remaining stock after sales: 503
# Amount of new Stocks: 53
# Updated stock after restocking: 556
# Number of full cartons: 46
# Remaining stocks: 10
