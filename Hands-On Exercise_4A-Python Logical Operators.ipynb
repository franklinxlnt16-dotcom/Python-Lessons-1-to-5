# %% [markdown]
# ## Hands-On 1

# %%
username_correct = True
password_correct = True
account_locked = False
if password_correct and username_correct and not account_locked:
    print("Access Granted")
else:
    print("Access Denied")
# Out:
# Access Granted

# %%
username_correct = True
password_correct = False
account_locked = False
if password_correct and username_correct and  account_locked:
    print("Access Granted")
else:
    print("Access Denied")
# Out:
# Access Denied

# %% [markdown]
# ## Hands-On 2

# %%
score = 85
participated = True
low_income = False
qualification_criteria = score>80 and (participated==True or low_income==True)
if qualification_criteria == True:
    print("Congratulations!\nScholarship Approved")
else:
    print("Scholarship Not Approved")
# Out:
# Congratulations!
# Scholarship Approved

# %%
score = 85
participated = False
low_income = False
qualification_criteria = score>80 and (participated==True or low_income==True)
if qualification_criteria == True:
    print("Congratulations!\nScholarship Approved")
else:
    print("Scholarship Not Approved")
# Out:
# Scholarship Not Approved

# %% [markdown]
# ## Hands-On 3

# %%
cpu_usage = 75
memory_usage = 92
disk_usge = 60
server_condition = cpu_usage>90 or memory_usage>90 or disk_usage>95
if server_condition == False:
    print("☑ System Healthy")
else:
    print("⚠ Critical Alert")
# Out:
# ⚠ Critical Alert

# %%
cpu_usage = 75
memory_usage = 92
disk_usge = 60
server_condition = cpu_usage>90 or memory_usage>90 or disk_usage>95
if server_condition == True:
    print("☑ System Healthy")
else:
    print("⚠ Critical Alert")
# Out:
# ☑ System Healthy

# %% [markdown]
# ## Bonus Challenge

# %%
logged_in = True
item_in_stock = True
sufficient_balance = True
account_suspended = False
order_criteria = logged_in and item_in_stock and sufficient_balance and not account_suspended
if order_criteria == True:
    print("☑ Order Confirmed")
else:
    print("Order Failed")
# Out:
# ☑ Order Confirmed

# %%
logged_in = True
item_in_stock = True
sufficient_balance = True
account_suspended = False
order_criteria = logged_in and item_in_stock and sufficient_balance and  account_suspended
if order_criteria == True:
    print("☑ Order Confirmed")
else:
    print("Order Failed")
# Out:
# Order Failed
